# %% [markdown]
# # KAHOOT - GRAPHS ALGORITHMS

# %% [markdown]
# ## Câu 1
# Mục tiêu của duyệt đồ thị (traversal) là tiếp cận toàn bộ đỉnh trong đồ thị
#
# ##### A. True
# B. False

# %% [markdown]
# ##  Câu 2
# Khi duyệt đồ thị, DFS và BFS đều là completed search và dùng stack để lưu các đỉnh chờ được duyệt
#
# A. True
# ##### B. False

# %% [markdown]
# ##  Câu 3
# Trong bài toán tìm đường đi, BFS và DFS đều là Informed Search
#
# A. True
# ##### B. False

# %% [markdown]
# ##  Câu 4
# Hàm ước lượng chi phí của Best-First Search (Greedy) là phiên bản cải tiến của A* Search
#
# A. True
# ##### B. False

# %% [markdown]
# ##  Câu 5
# Thuật toán đảm bảo tìm đường đi tối ưu nhất (optimal path) là:
#
# ##### A. BFS
# B. DFS
# <br> C. Best-First Search (Greedy Search)
# <br> D. A* Star Search

# %% [markdown]
# ##  Câu 6
# Thuật toán nào duyệt nhiều node nhất khi tìm đường đi từ S đến G?
# ![2020-12-21.png](attachment:2020-12-21.png)
# <br>A. A* Star Search
# ##### B. BFS
# C. DFS
# <br> D. Best-First Search (Greedy Search)

# %% [markdown]
# ##  Câu 7
# Mọi đồ thị có hướng đều có ít nhất 1 chuỗi thứ tự topological
#
# A. True
# ##### B. False

# %% [markdown]
# ##  Câu 8
# Giải thuật nào của bài toán topological sorting có mục tiêu là tìm node gốc?
#
# A. DFS
# ##### B. Kahn's Algorithm

# %% [markdown]
# ##  Câu 9
# Pattern recognition của Graphs Algorithm là
#
# ##### A. Tập đỉnh tương ứng với các đối tượng đồng dạng
# ##### B. Tập cạnh tương ứng với các quan hệ giữa các đối tượng
# ##### C. Các điều kiện ràng buộc giữa các đối tượng
# ##### D. Trọng số của các mối quan hệ giữa các đối tượng
#
# (Tất cả đều đúng)

# %% [markdown]
# ##  Câu 10
#
# Ứng dụng của Graph Algorithms
#
# ##### A. Kiểm tra các tính chất của đồ thị
# ##### B. Tìm đường đi đến điểm đích
# ##### C. Sắp xếp thự tự công việc trong 1 dự án
# ##### D. Phân vùng ảnh (Image Segmentation)
#
# (Tất cả đều đúng)
